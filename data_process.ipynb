# %%
import pandas as pd

# %%
data = pd.read_csv('./dataset/qa_corpus.csv')

# %%
data
# Out:
#                                                      qid    question  \
# 0                                                      1       补发网银盾
# 1                                                      2        代发工资
# 2                                                      3     对帐单查询打印
# 3                                                      4      理财产品取号
# 4                                                      5        密码修改
# 5                                                      6    查询名下所有账户
# 6                                                      9    交易流水明细证明
# 7                                                     10       个人结售汇
# 8                                                     11        现金取款
# 9                                                     12        账户销户
# 10                                                    13        转账业务
# 11                                                    15        现金存款
# 12                                                    16       贵金属业务
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32526 entries, 0 to 32525
# Data columns (total 3 columns):
# qid         32526 non-null object
# question    32525 non-null object
# answer      32525 non-null object
# dtypes: object(3)
# memory usage: 762.4+ KB

# %%
data.dropna().info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 32525 entries, 0 to 32525
# Data columns (total 3 columns):
# qid         32525 non-null object
# question    32525 non-null object
# answer      32525 non-null object
# dtypes: object(3)
# memory usage: 1016.4+ KB

# %%
clean_data = data.dropna()

# %%
clean_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 32525 entries, 0 to 32525
# Data columns (total 3 columns):
# qid         32525 non-null object
# question    32525 non-null object
# answer      32525 non-null object
# dtypes: object(3)
# memory usage: 1016.4+ KB

# %%
clean_data.iloc[32509]
# Out:
# qid                                                     69068
# question                                            储蓄卡卡片状态查询
# answer      储蓄卡卡片状态查询：您可以进入我行主页点击右侧“个人银行普通版”，选择储蓄卡，输入卡号、查询...
# Name: 32509, dtype: object

# %%
clean_data = clean_data[:32522]

# %%
clean_data
# Out:
#          qid    question                                             answer
# 0          1       补发网银盾     您可以到智慧柜员机办理此项业务，方便快捷，节省您的宝贵时间哦。若去柜台办理，请刷身份证取号。
# 1          2        代发工资            您要办理的是对公开户、销户、签约及其他业务。请刷身份证，小龙人来帮您取个号吧。
# 2          3     对帐单查询打印            您要办理的是对公开户、销户、签约及其他业务。请刷身份证，小龙人来帮您取个号吧。
# 3          4      理财产品取号                                        请说出您需要办理的业务
# 4          5        密码修改                        请您带上身份证到自助柜员机办理，简单快捷，操作容易哦。
# 5          6    查询名下所有账户                    您可以到智慧柜员机办理此项业务，如需到柜台办理，请刷身份证取号
# 6          9    交易流水明细证明                    您可以到智慧柜员机办理此项业务，如需到柜台办理，请刷身份证取号
# 7         10       个人结售汇  电视墙上有实时汇率表哦，您可以看看，如果您需要购汇或换汇，请到自助柜员机办理，如果您要取现钞...
# 8         11        现金取款            人民币百元钞2万以内可直接在ATM机办理，2万以上请刷身份证取号到柜台办理哦。
# 9         12        账户销户          您要办理的是个人转账、挂失、销户、修改密码业务。请刷身份证，小龙人来帮您取个号吧。
# 10        13        转账业务  5万元以内转账，可以直接在ATM办理；五万以上请刷身份证取号至柜台办理。您也可以通过网上银行...
# ...

# %%
clean_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32522 entries, 0 to 32521
# Data columns (total 3 columns):
# qid         32522 non-null object
# question    32522 non-null object
# answer      32522 non-null object
# dtypes: object(3)
# memory usage: 762.3+ KB

# %%
clean_data = clean_data.drop_duplicates(subset=['question'])

# %%
clean_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 32499 entries, 0 to 32521
# Data columns (total 3 columns):
# qid         32499 non-null object
# question    32499 non-null object
# answer      32499 non-null object
# dtypes: object(3)
# memory usage: 1015.6+ KB

# %%
clean_data.to_csv('./dataset/clean_qa_corpus.csv')
